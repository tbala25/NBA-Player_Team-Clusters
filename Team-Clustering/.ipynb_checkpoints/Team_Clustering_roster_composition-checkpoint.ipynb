# %%
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import cluster
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)
from sklearn.preprocessing import StandardScaler


#read players_cleaned
players_cleaned = pd.read_csv('../Player-Clustering/players_cleaned.csv')

#read players_clustered
players_clustered = pd.read_csv('../Player-Clustering/players_clustered.csv')

#read team_cleaned
cleaned_team = pd.read_csv('teams_cleaned.csv')

# %%
players_cleaned.head()
# Out:
#    Unnamed: 0                   Player Pos_x  Age_x Tm_x  G_x  GS  MP_x   FG  \
# 0           0   Alex Abrines\abrinal01    SG     24  OKC   75   8  1134  5.0
# 1           1       Quincy Acy\acyqu01    PF     27  BRK   70   8  1359  4.6
# 2           2   Steven Adams\adamsst01     C     24  OKC   76  76  2487  8.9
# 3           3    Bam Adebayo\adebaba01     C     20  MIA   69  19  1368  6.4
# 4           4  Arron Afflalo\afflaar01    SG     32  ORL   53   3   682  4.7
#
#     FGA    FG%   3P   3PA    3P%   2P   2PA    2P%   FT  FTA    FT%  ORB  DRB  \
# 0  12.7  0.395  3.7   9.7  0.380  1.4   3.1  0.443  1.7  2.0  0.848  1.1  3.9
# 1  13.0  0.356  3.6  10.4  0.349  1.0   2.6  0.384  1.8  2.1  0.817  1.4  7.8
# 2  14.2  0.629  0.0   0.0  0.000  8.9  14.2  0.631  3.2  5.7  0.559  7.7  6.0
# 3  12.5  0.512  0.0   0.3  0.000  6.4  12.2  0.523  4.7  6.6  0.721  4.3  9.7
# 4  11.6  0.401  1.9   5.0  0.386  2.7   6.6  0.413  1.6  1.9  0.846  0.3  4.5
#
#     TRB  AST  STL  BLK  TOV   PF   PTS   ORtg  DRtg   PER    TS%   3PAr  \
# 0   5.0  1.2  1.7  0.4  1.1  5.4  15.4  116.0   110   9.0  0.567  0.759
# 1   9.2  2.0  1.2  1.0  2.1  5.3  14.7   99.0   110   8.2  0.525  0.800
# 2  13.7  1.8  1.8  1.6  2.6  4.3  21.1  125.0   107  20.6  0.630  0.003
# 3  14.0  3.7  1.2  1.5  2.4  5.1  17.5  116.0   105  15.7  0.570  0.021
# 4   4.7  2.2  0.3  0.6  1.5  4.0  12.8   98.0   115   5.8  0.516  0.432
#
#      FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  \
# 0  0.158   2.5   8.9   5.6   3.4   1.7   0.6   7.4  12.7  1.3  1.0  2.2
# 1  0.164   3.1  17.1  10.0   6.0   1.2   1.6  13.3  14.4 -0.1  1.1  1.0
# 2  0.402  16.6  13.9  15.3   5.5   1.8   2.8  13.3  16.7  6.7  3.0  9.7
# 3  0.526   9.7  21.6  15.6  11.0   1.2   2.5  13.6  15.9  2.3  1.9  4.2
# 4  0.160   0.6  10.1   5.3   6.2   0.3   1.1  10.8  12.5 -0.1  0.2  0.1
#
#    WS/48  OBPM  DBPM  BPM  VORP  as_caliber
# 0  0.094  -0.5  -1.7 -2.2  -0.1           0
# 1  0.036  -2.0  -0.2 -2.2  -0.1           0
# 2  0.187   2.2   1.1  3.3   3.3           1
# 3  0.148  -1.6   1.8  0.2   0.8           0
# 4  0.009  -4.1  -1.8 -5.8  -0.7           0

# %%
#Take out TOT rows, only keep team rows
players = players_cleaned.loc[players_cleaned['Tm_x'] != 'TOT']

#TODO Need to sort on Minutes and only take top 9 per team...
#get set of teams
#for each team in set of teams take top 9s rows of df sorted on min
players_by_team_min = players.sort_values(['Tm_x', 'MP_x'], ascending=[True, False])
top9 = pd.DataFrame()
teams = set(players['Tm_x'])

for i in teams:
    team_df = players_by_team_min[players_by_team_min['Tm_x']==i]
    top9 = top9.append(team_df.iloc[:10,:], ignore_index=True)


#only keep player and team
players = top9[['Player','Tm_x']]

#only keep player and cluster
players_cluster = players_clustered[['Player', 'Cluster']]

# %%
#Merge player and team with cluster
player_team_cluster = players.merge(players_cluster, left_on = 'Player', right_on = 'Player', how = 'left')

# %%
player_team_cluster.head()
# Out:
#                    Player Tm_x  Cluster
# 0  James Harden\hardeja01  HOU        5
# 1   P.J. Tucker\tuckepj01  HOU        0
# 2  Trevor Ariza\arizatr01  HOU        0
# 3   Eric Gordon\gordoer01  HOU        4
# 4  Clint Capela\capelca01  HOU        1

# %%
cluster_dummies = pd.get_dummies(player_team_cluster['Cluster'])

# %%
#player_team_cluster_dummies = player_team_cluster.merge(cluster_dummies, left_on = 'Player', right_on = 'Player', how = 'left')
cluster_dummies['Team'] = player_team_cluster['Tm_x']
roster_composition = cluster_dummies.groupby(['Team']).sum()

# %%
#add some team stats to roster composition
roster_composition = pd.DataFrame(roster_composition)
roster_composition['Team'] = roster_composition.index

team_stats = cleaned_team[['0','3PAr', 'FTr', 'Pace']]
ros_comp_team_stats = roster_composition.merge(team_stats, left_on='Team', right_on='0')

# %%
#Z score standardization
team_standardized  = pd.DataFrame(StandardScaler().fit_transform(ros_comp_team_stats.select_dtypes(exclude='object')))

# %%
#PCA CLUSTERING

#DECIDED ON # of Components = 2 to represent 29% of variance
pca = PCA(n_components = 2)
principalComponents = pca.fit_transform(team_standardized.select_dtypes(exclude='object'))
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', ])#'principal component 3'])#, 'principal component 4', 'principal component 5', 'principal component 6', 'principal component 7'])
np.set_printoptions(precision=2, suppress=True)
print('Total Variance: ' + str(sum(pca.explained_variance_)))
print('Percentage of Var represented by PC: ')
print(pca.explained_variance_/sum(pca.explained_variance_))
print('Cumulative Percentage of Var represented by PC: ')
print(np.cumsum(pca.explained_variance_/sum(pca.explained_variance_)))
# Out:
# Total Variance: 4.574100601179348
# Percentage of Var represented by PC:
# [0.53 0.47]
# Cumulative Percentage of Var represented by PC:
# [0.53 1.  ]

# %%
Sum_of_squared_distances = []
K = range(2,10)
for k in K:
    km = cluster.KMeans(n_clusters=k)
    km = km.fit(principalDf)
    Sum_of_squared_distances.append(km.inertia_)
    cluster_labels = km.labels_
    silhouette_avg = silhouette_score(principalDf, cluster_labels)
    print("For n_clusters =", k,
          "The average silhouette_score is :", silhouette_avg)
    
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.32763731275629043
# For n_clusters = 3 The average silhouette_score is : 0.39956992456016877
# For n_clusters = 4 The average silhouette_score is : 0.3773944418990562
# For n_clusters = 5 The average silhouette_score is : 0.3271263712684747
# For n_clusters = 6 The average silhouette_score is : 0.4148747374553143
# For n_clusters = 7 The average silhouette_score is : 0.39337423811567584
# For n_clusters = 8 The average silhouette_score is : 0.406148806146812
# For n_clusters = 9 The average silhouette_score is : 0.4000870252191578

# %%
k = 6
kmeans = cluster.KMeans(n_clusters=k)
kmeans.fit(principalDf)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

principalDf['Team'] = ros_comp_team_stats['Team']
principalDf['Cluster'] = labels
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-46e888ceef81> in <module>
#       1 k = 6
#       2 kmeans = cluster.KMeans(n_clusters=k)
# ----> 3 kmeans.fit(principalDf)
#       4
#       5 labels = kmeans.labels_
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#     885         """
#     886         random_state = check_random_state(self.random_state)
# --> 887         X = self._check_fit_data(X)
#     888
#     889         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _check_fit_data(self, X)
#     856     def _check_fit_data(self, X):
#     857         """Verify that the number of samples given is larger than k"""
# --> 858         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32])
#     859         if X.shape[0] < self.n_clusters:
#     860             raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'WAS'

# %%
plt.figure()
plt.ylim(-10, 10)
plt.xlim(-10, 10)
sns.scatterplot(x='principal component 1', y ='principal component 2', hue ="Cluster", data = principalDf, legend = False )

# %%
#principalDf.to_csv('teams_roster_clustered.csv')

# %%
final = ros_comp_team_stats.merge(principalDf, left_on = 'Team', right_on = 'Team')
final.to_csv('teams_roster_clustered.csv')
