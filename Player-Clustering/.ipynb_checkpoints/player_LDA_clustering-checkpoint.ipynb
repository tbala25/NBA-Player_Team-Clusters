# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
import math

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import cluster
from sklearn.decomposition import PCA

from scipy.spatial import distance

# %%
##LOADING CLEANED DATA

players_2018 = pd.read_csv('players_cleaned.csv')
players_2018 = players_2018.drop(['Unnamed: 0'], axis = 1)
players_2018 = players_2018.fillna(0)
players_2018.shape
# Out:
# (1056, 51)

# %%
players_2018.head()
# Out:
#                     Player Pos_x  Age_x Tm_x  G_x  GS  MP_x   FG   FGA    FG%  \
# 0   Alex Abrines\abrinal01    SG     24  OKC   75   8  1134  5.0  12.7  0.395
# 1       Quincy Acy\acyqu01    PF     27  BRK   70   8  1359  4.6  13.0  0.356
# 2   Steven Adams\adamsst01     C     24  OKC   76  76  2487  8.9  14.2  0.629
# 3    Bam Adebayo\adebaba01     C     20  MIA   69  19  1368  6.4  12.5  0.512
# 4  Arron Afflalo\afflaar01    SG     32  ORL   53   3   682  4.7  11.6  0.401
#
#     3P   3PA    3P%   2P   2PA    2P%   FT  FTA    FT%  ORB  DRB   TRB  AST  \
# 0  3.7   9.7  0.380  1.4   3.1  0.443  1.7  2.0  0.848  1.1  3.9   5.0  1.2
# 1  3.6  10.4  0.349  1.0   2.6  0.384  1.8  2.1  0.817  1.4  7.8   9.2  2.0
# 2  0.0   0.0  0.000  8.9  14.2  0.631  3.2  5.7  0.559  7.7  6.0  13.7  1.8
# 3  0.0   0.3  0.000  6.4  12.2  0.523  4.7  6.6  0.721  4.3  9.7  14.0  3.7
# 4  1.9   5.0  0.386  2.7   6.6  0.413  1.6  1.9  0.846  0.3  4.5   4.7  2.2
#
#    STL  BLK  TOV   PF   PTS   ORtg  DRtg   PER    TS%   3PAr    FTr  ORB%  \
# 0  1.7  0.4  1.1  5.4  15.4  116.0   110   9.0  0.567  0.759  0.158   2.5
# 1  1.2  1.0  2.1  5.3  14.7   99.0   110   8.2  0.525  0.800  0.164   3.1
# 2  1.8  1.6  2.6  4.3  21.1  125.0   107  20.6  0.630  0.003  0.402  16.6
# 3  1.2  1.5  2.4  5.1  17.5  116.0   105  15.7  0.570  0.021  0.526   9.7
# 4  0.3  0.6  1.5  4.0  12.8   98.0   115   5.8  0.516  0.432  0.160   0.6
#
#    DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  \
# 0   8.9   5.6   3.4   1.7   0.6   7.4  12.7  1.3  1.0  2.2  0.094  -0.5  -1.7
# 1  17.1  10.0   6.0   1.2   1.6  13.3  14.4 -0.1  1.1  1.0  0.036  -2.0  -0.2
# 2  13.9  15.3   5.5   1.8   2.8  13.3  16.7  6.7  3.0  9.7  0.187   2.2   1.1
# 3  21.6  15.6  11.0   1.2   2.5  13.6  15.9  2.3  1.9  4.2  0.148  -1.6   1.8
# 4  10.1   5.3   6.2   0.3   1.1  10.8  12.5 -0.1  0.2  0.1  0.009  -4.1  -1.8
#
#    BPM  VORP  as_caliber
# 0 -2.2  -0.1           0
# 1 -2.2  -0.1           0
# 2  3.3   3.3           1
# 3  0.2   0.8           0
# 4 -5.8  -0.7           0

# %%
#FEATURE SELECTION

#DROP FEATURES THAT ARE RELATED TO PLAYER SUCCESS
## as_caliber, VORP, BPM, WS/48, WS, GS G_x, MP_x 

#drop success metrics, features that have a strong correlation with how good a player is not style of play
# players_select = players_2018.drop(['as_caliber', 'VORP', 'BPM', 'WS/48', 'MP_x', 'GS', 'G_x', 'MP_x'], axis = 1)

#drop percent metrics
#this is pretty good
#gives me a weird role player cluster
#gives me cluster for all around guard and all around big...
#players_select = players_2018.drop(['Age_x', 'FG','FGA', 'FG%', '3P%', '2P%', 'FT%', 'TRB', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'PER','as_caliber', 'TS%', 'VORP', 'OBPM', 'DBPM', 'BPM', 'WS', 'WS/48', 'USG%', 'GS', 'G_x', 'MP_x'], axis = 1)

#drop raw metrics
#players_select = players_2018.drop(['Age_x', 'FG','FGA','3P','3PA','2P','2PA','FT','FTA','ORB','DRB','TRB','AST','STL','BLK','TOV','PER','as_caliber', 'TS%', 'VORP', 'OBPM', 'DBPM', 'BPM', 'WS', 'WS/48', 'USG%', 'GS', 'G_x', 'MP_x'], axis = 1)

#don't drop any metrics
#pretty decent, has weird cluster of stars that are central on pc1 pc2
players_select = players_2018


players_select.head()
# Out:
#                     Player Pos_x  Age_x Tm_x  G_x  GS  MP_x   FG   FGA    FG%  \
# 0   Alex Abrines\abrinal01    SG     24  OKC   75   8  1134  5.0  12.7  0.395
# 1       Quincy Acy\acyqu01    PF     27  BRK   70   8  1359  4.6  13.0  0.356
# 2   Steven Adams\adamsst01     C     24  OKC   76  76  2487  8.9  14.2  0.629
# 3    Bam Adebayo\adebaba01     C     20  MIA   69  19  1368  6.4  12.5  0.512
# 4  Arron Afflalo\afflaar01    SG     32  ORL   53   3   682  4.7  11.6  0.401
#
#     3P   3PA    3P%   2P   2PA    2P%   FT  FTA    FT%  ORB  DRB   TRB  AST  \
# 0  3.7   9.7  0.380  1.4   3.1  0.443  1.7  2.0  0.848  1.1  3.9   5.0  1.2
# 1  3.6  10.4  0.349  1.0   2.6  0.384  1.8  2.1  0.817  1.4  7.8   9.2  2.0
# 2  0.0   0.0  0.000  8.9  14.2  0.631  3.2  5.7  0.559  7.7  6.0  13.7  1.8
# 3  0.0   0.3  0.000  6.4  12.2  0.523  4.7  6.6  0.721  4.3  9.7  14.0  3.7
# 4  1.9   5.0  0.386  2.7   6.6  0.413  1.6  1.9  0.846  0.3  4.5   4.7  2.2
#
#    STL  BLK  TOV   PF   PTS   ORtg  DRtg   PER    TS%   3PAr    FTr  ORB%  \
# 0  1.7  0.4  1.1  5.4  15.4  116.0   110   9.0  0.567  0.759  0.158   2.5
# 1  1.2  1.0  2.1  5.3  14.7   99.0   110   8.2  0.525  0.800  0.164   3.1
# 2  1.8  1.6  2.6  4.3  21.1  125.0   107  20.6  0.630  0.003  0.402  16.6
# 3  1.2  1.5  2.4  5.1  17.5  116.0   105  15.7  0.570  0.021  0.526   9.7
# 4  0.3  0.6  1.5  4.0  12.8   98.0   115   5.8  0.516  0.432  0.160   0.6
#
#    DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  \
# 0   8.9   5.6   3.4   1.7   0.6   7.4  12.7  1.3  1.0  2.2  0.094  -0.5  -1.7
# 1  17.1  10.0   6.0   1.2   1.6  13.3  14.4 -0.1  1.1  1.0  0.036  -2.0  -0.2
# 2  13.9  15.3   5.5   1.8   2.8  13.3  16.7  6.7  3.0  9.7  0.187   2.2   1.1
# 3  21.6  15.6  11.0   1.2   2.5  13.6  15.9  2.3  1.9  4.2  0.148  -1.6   1.8
# 4  10.1   5.3   6.2   0.3   1.1  10.8  12.5 -0.1  0.2  0.1  0.009  -4.1  -1.8
#
#    BPM  VORP  as_caliber
# 0 -2.2  -0.1           0
# 1 -2.2  -0.1           0
# 2  3.3   3.3           1
# 3  0.2   0.8           0
# 4 -5.8  -0.7           0

# %%
##STANDARDIZE DATA FOR LDA
#p_standardized  = pd.DataFrame(StandardScaler().fit_transform(players_select.select_dtypes(exclude='object')))
p_standardized = players_select.select_dtypes(exclude='object')

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

LDA = LinearDiscriminantAnalysis(n_components=2, solver='eigen', shrinkage='auto' )
LDA_reduced_df = LDA.fit(p_standardized,players_2018['Pos_x']).transform(p_standardized)
LDA_reduced_df = pd.DataFrame(LDA_reduced_df)
LDA_reduced_df['Player'] = players_2018['Player']
LDA_reduced_df['Pos_x'] = players_2018['Pos_x']


LDA.score(p_standardized,players_2018['Pos_x'])
# Out:
# 0.6145833333333334

# %%
plt.figure()
sns.scatterplot(x=0, y =1, hue ="Pos_x", data = LDA_reduced_df, legend = False )

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

LDA = LinearDiscriminantAnalysis(n_components=2, solver='svd' )
LDA_reduced_df = LDA.fit(p_standardized,players_2018['Pos_x']).transform(p_standardized)
LDA_reduced_df = pd.DataFrame(LDA_reduced_df)
LDA_reduced_df['Player'] = players_2018['Player']
LDA_reduced_df['Pos_x'] = players_2018['Pos_x']


LDA.score(p_standardized,players_2018['Pos_x'])
# Out:
# 0.6704545454545454

# %%
plt.figure()
sns.scatterplot(x=0, y =1, hue ="Pos_x", data = LDA_reduced_df, legend = False )

# %%
## Number of Cluster Analysis LDA = 2

#DECIDED ON # of Components = 2 to represent 29% of variance
# pca = PCA(n_components = 2)
# principalComponents = pca.fit_transform(x_standardized.select_dtypes(exclude='object'))
# principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', ])#'principal component 3'])#, 'principal component 4', 'principal component 5', 'principal component 6', 'principal component 7'])
LDA = LinearDiscriminantAnalysis(n_components=2, solver='svd' )
LDA_reduced_df = LDA.fit(p_standardized,players_2018['Pos_x']).transform(p_standardized)
LDA_reduced_df = pd.DataFrame(LDA_reduced_df, columns = ['principal component 1', 'principal component 2', ])

Sum_of_squared_distances = []
K = range(2,10)
for k in K:
    km = cluster.KMeans(n_clusters=k)
    km = km.fit(LDA_reduced_df)
    Sum_of_squared_distances.append(km.inertia_)
    cluster_labels = km.labels_
    silhouette_avg = silhouette_score(LDA_reduced_df, cluster_labels)
    print("For n_clusters =", k,
          "The average silhouette_score is :", silhouette_avg)
    
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.43421388597167015
# For n_clusters = 3 The average silhouette_score is : 0.47757212914293934
# For n_clusters = 4 The average silhouette_score is : 0.3867134654964841
# For n_clusters = 5 The average silhouette_score is : 0.37506316499862274
# For n_clusters = 6 The average silhouette_score is : 0.34298258311891483
# For n_clusters = 7 The average silhouette_score is : 0.3423488445200187
# For n_clusters = 8 The average silhouette_score is : 0.3417394207303701
# For n_clusters = 9 The average silhouette_score is : 0.331811168081133

# %%
##CLUSTER ANALYSIS


k = 8
kmeans = cluster.KMeans(n_clusters=k)
kmeans.fit(LDA_reduced_df)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

LDA_reduced_df['Cluster'] = labels
LDA_reduced_df['Player'] = players_2018['Player']
LDA_reduced_df['Pos_x'] = players_2018['Pos_x']
LDA_reduced_df
# Out:
#       principal component 1  principal component 2  Cluster  \
# 0                  0.483899              -1.529279        3
# 1                 -0.176822              -1.893052        3
# 2                 -2.850465               0.244767        2
# 3                 -2.697904               0.933887        7
# 4                  0.488886              -1.097125        4
# 5                 -2.888002               0.564481        7
# 6                 -1.969579               0.572276        2
# 7                 -2.754556               0.558972        2
# 8                  1.395877               0.994498        5
# 9                 -0.512310              -0.081995        0
# 10                -1.235904              -2.164113        0
# 11                -0.077249              -0.994115        0
# 12                -1.233312              -0.065174        2
# 13                -1.142764              -1.598974        0
# 14                -2.450632               0.473751        2
# 15                -1.478246               0.586143        2
# 16                -0.156368              -0.695617        0
# 17                -0.248494              -1.135875        0
# 18                 2.455913              -0.150846        1
# 19                -0.235087              -2.770311        3
# 20                 1.376817               0.523468        5
# 21                 0.335405              -1.105710        3
# 22                -2.314475              -0.147814        2
# 23                -2.500681              -0.227950        2
# 24                -1.872594              -0.036585        2
# 25                -2.633218              -0.370349        2
# 26                -2.819424              -0.450485        2
# 27                -2.191337              -0.259120        2
# 28                -1.701073               0.179107        2
# 29                -1.887278               0.098971        2
# 30                -1.259191               0.290336        2
# 31                 1.613338               1.546041        1
# 32                 0.141522              -1.485014        3
# 33                -0.052427              -1.331754        0
# 34                 0.563629              -2.166554        3
# 35                 0.116132              -1.697525        3
# 36                -0.077817              -1.544265        3
# 37                 0.538239              -2.379065        3
# 38                -0.159952              -1.376281        0
# 39                -0.353901              -1.223021        0
# 40                 0.262155              -2.057821        3
# 41                 0.170883              -0.592372        0
# 42                 1.917898               0.116956        1
# 43                 0.758748              -0.657992        4
# 44                 1.349198               0.120257        4
# 45                 2.503709               3.380000        6
# 46                -0.166382              -1.057077        0
# 47                 0.420373              -0.710347        4
# 48                 0.864710               0.743383        5
# 49                 1.108865              -1.599186        3
# ...                     ...                    ...      ...
# 1006              -1.783931              -1.923010        0
# 1007               0.391697              -0.766242        4
# 1008              -1.338413               1.738224        2
# 1009               0.614909              -0.899160        4
# 1010               0.972592              -2.318481        3
# 1011               1.751138               0.105818        4
# 1012              -1.413612              -1.297105        0
# 1013               2.527445              -1.819429        4
# 1014              -0.247813              -0.250588        0
# 1015               0.267404              -0.281323        0
# 1016              -0.328544              -0.416393        0
# 1017              -0.521604              -1.439005        0
# 1018              -0.006387              -1.469740        3
# 1019              -0.602334              -1.604810        0
# 1020              -0.107231              -0.347491        0
# 1021               0.407986              -0.378226        4
# 1022              -0.187962              -0.513296        0
# 1023               0.415092              -0.029308        5
# 1024              -0.246296              -1.957995        3
# 1025              -0.241346              -0.734170        0
# 1026              -1.342243              -1.319488        0
# 1027              -0.198104              -0.905334        0
# 1028              -3.569388              -0.087710        7
# 1029              -3.642876              -0.109566        7
# 1030              -2.687294              -0.311936        2
# 1031              -3.617045              -0.083789        7
# 1032              -3.690533              -0.105645        7
# 1033              -2.734951              -0.308014        2
# 1034              -3.731110              -0.315110        7
# 1035              -3.804598              -0.336967        7
# 1036              -2.849016              -0.539336        2
# 1037               0.484151               0.354394        5
# 1038              -0.993544              -0.425936        0
# 1039               1.580548              -2.849606        3
# 1040               1.192145              -0.055431        4
# 1041               1.107066              -1.460672        4
# 1042              -0.871383              -1.228184        0
# 1043              -1.702968               0.229618        2
# 1044              -2.408955               1.314528        7
# 1045              -2.232307               1.021708        2
# 1046              -2.419006               0.835413        2
# 1047              -2.454835               1.126353        7
# 1048              -2.278187               0.833533        2
# 1049              -2.464886               0.647238        2
# 1050              -2.669923               1.127737        7
# 1051              -2.493275               0.834917        2
# 1052              -2.679974               0.648622        2
# 1053               0.571167              -0.394704        4
# 1054              -3.529996               1.099903        7
# 1055              -2.461073               1.205520        7
#
#                                Player Pos_x
# 0              Alex Abrines\abrinal01    SG
# 1                  Quincy Acy\acyqu01    PF
# 2              Steven Adams\adamsst01     C
# 3               Bam Adebayo\adebaba01     C
# 4             Arron Afflalo\afflaar01    SG
# 5              Cole Aldrich\aldrico01     C
# 6         LaMarcus Aldridge\aldrila01     C
# 7             Jarrett Allen\allenja01     C
# 8              Kadeem Allen\allenka01    PG
# 9                Tony Allen\allento01    SF
# 10          Al-Farouq Aminu\aminual01    PF
# 11          Justin Anderson\anderju01    SF
# 12            Kyle Anderson\anderky01    SF
# 13            Ryan Anderson\anderry01    PF
# 14             Ike Anigbogu\anigbik01     C
# 15    Giannis Antetokounmpo\antetgi01    PF
# 16          Carmelo Anthony\anthoca01    PF
# 17               OG Anunoby\anunoog01    SF
# 18         Ryan Arcidiacono\arcidry01    PG
# 19             Trevor Ariza\arizatr01    SF
# 20           Darrell Arthur\arthuda01    PF
# 21              Jamel Artis\artisja01    SG
# 22                 Omer Asik\asikom01     C
# 23                 Omer Asik\asikom01     C
# 24                 Omer Asik\asikom01     C
# 25                 Omer Asik\asikom01     C
# 26                 Omer Asik\asikom01     C
# 27                 Omer Asik\asikom01     C
# 28                 Omer Asik\asikom01     C
# 29                 Omer Asik\asikom01     C
# 30                 Omer Asik\asikom01     C
# 31            D.J. Augustin\augusdj01    PG
# 32             Luke Babbitt\babbilu01    SF
# 33             Luke Babbitt\babbilu01    SF
# 34             Luke Babbitt\babbilu01    SF
# 35             Luke Babbitt\babbilu01    SF
# 36             Luke Babbitt\babbilu01    SF
# 37             Luke Babbitt\babbilu01    SF
# 38             Luke Babbitt\babbilu01    SF
# 39             Luke Babbitt\babbilu01    SF
# 40             Luke Babbitt\babbilu01    SF
# 41             Dwayne Bacon\bacondw01    SG
# 42                Ron Baker\bakerro01    SG
# 43             Wade Baldwin\baldwwa01    PG
# 44                Lonzo Ball\balllo01    PG
# 45               J.J. Barea\bareajo01    PG
# 46          Harrison Barnes\barneha02    PF
# 47              Will Barton\bartowi01    SG
# 48            Nicolas Batum\batumni01    SG
# 49           Jerryd Bayless\bayleje01    SG
# ...                               ...   ...
# 1006            Jacob Wiley\wileyja01    PF
# 1007         Damien Wilkins\wilkida02    SF
# 1008          Alan Williams\willial03    PF
# 1009          C.J. Williams\willicj01    SG
# 1010       Derrick Williams\willide02    PF
# 1011           Lou Williams\willilo02    SG
# 1012        Marvin Williams\willima02    PF
# 1013          Matt Williams\willima05    SG
# 1014          Troy Williams\willitr02    SF
# 1015          Troy Williams\willitr02    SF
# 1016          Troy Williams\willitr02    SF
# 1017          Troy Williams\willitr02    SF
# 1018          Troy Williams\willitr02    SF
# 1019          Troy Williams\willitr02    SF
# 1020          Troy Williams\willitr02    SF
# 1021          Troy Williams\willitr02    SF
# 1022          Troy Williams\willitr02    SF
# 1023            D.J. Wilson\wilsodj01    PF
# 1024           Jamil Wilson\wilsoja02    SF
# 1025        Justise Winslow\winslju01    PF
# 1026            Jeff Withey\witheje01     C
# 1027           Nate Wolters\woltena01    PG
# 1028         Brandan Wright\wrighbr03    PF
# 1029         Brandan Wright\wrighbr03    PF
# 1030         Brandan Wright\wrighbr03    PF
# 1031         Brandan Wright\wrighbr03    PF
# 1032         Brandan Wright\wrighbr03    PF
# 1033         Brandan Wright\wrighbr03    PF
# 1034         Brandan Wright\wrighbr03    PF
# 1035         Brandan Wright\wrighbr03    PF
# 1036         Brandan Wright\wrighbr03    PF
# 1037           Delon Wright\wrighde01    PG
# 1038     Guerschon Yabusele\yabusgu01    PF
# 1039            James Young\youngja01    SG
# 1040              Joe Young\youngjo01    PG
# 1041             Nick Young\youngni01    SG
# 1042         Thaddeus Young\youngth01    PF
# 1043            Cody Zeller\zelleco01     C
# 1044           Tyler Zeller\zellety01     C
# 1045           Tyler Zeller\zellety01     C
# 1046           Tyler Zeller\zellety01     C
# 1047           Tyler Zeller\zellety01     C
# 1048           Tyler Zeller\zellety01     C
# 1049           Tyler Zeller\zellety01     C
# 1050           Tyler Zeller\zellety01     C
# 1051           Tyler Zeller\zellety01     C
# 1052           Tyler Zeller\zellety01     C
# 1053            Paul Zipser\zipsepa01    SF
# 1054             Ante Zizic\zizican01     C
# 1055            Ivica Zubac\zubaciv01     C
#
# [1056 rows x 5 columns]

# %%
plt.figure()
sns.scatterplot(x='principal component 1', y ='principal component 2', hue ="Cluster", data = LDA_reduced_df, legend = False )

# %%
players_2018['PC1'] = LDA_reduced_df['principal component 1']
players_2018['PC2'] = LDA_reduced_df['principal component 2']
players_2018['Cluster'] = LDA_reduced_df['Cluster']

# %%
players_2018.to_csv('players_clustered.csv')
